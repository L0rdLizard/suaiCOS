# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy import signal as sp

# %%
t = np.array([i * 0.01 for i in range(101)]) 
s = np.cos(2*np.pi*t) 
 
g = np.zeros(len(t)) 
g[len(t)//2] = 1 
y = sp.convolve(s, g)

# %%
plt.plot(y)
