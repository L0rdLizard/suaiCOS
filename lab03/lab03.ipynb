# %%
import sympy
import matplotlib.pyplot as plt

def z_transform(x, z):
    X = sum(x[n] / (n**(2*n)) for n in range(len(x)))
    return X

n_values = 100  
x = [1] * n_values  

z_values = [n**2 for n in range(1, n_values + 1)] 
X_z_values = [z_transform(x, z) for z in z_values] 

plt.plot(z_values, X_z_values)
plt.xlabel('z = n^2')
plt.ylabel('X(z)')
plt.title('Z-преобразование X(z) относительно z = n^2')
plt.grid()
plt.show()

# %%
import sympy
import lcapy as lc

n = lc.n
xk = 2**n * lc.exp(3j * n)
X0 = xk.ZT()
print(X0)


def z_transform(x, z):
    X = sum(x[n] * z**(-n) for n in range(len(x)))
    return X

n_values = 10  # количество значений 
x = [2**n for n in range(n_values)]  

z_value = sympy.Symbol('z')
X_z = z_transform(x, z_value)

a = 2
X_az = z_transform([a**n * x[n] for n in range(n_values)], 1 / a * z_value)

print(f"Z-преобразование X(z) = {X_z}")
print(f"Z-преобразование a^n*x(n) = X(a^(-1)z) = {X_az}")
# Out:
# z/(z - 2*exp(3*j))
# Z-преобразование X(z) = 1 + 2/z + 4/z**2 + 8/z**3 + 16/z**4 + 32/z**5 + 64/z**6 + 128/z**7 + 256/z**8 + 512/z**9
# Z-преобразование a^n*x(n) = X(a^(-1)z) = 1 + 8.0/z + 64.0/z**2 + 512.0/z**3 + 4096.0/z**4 + 32768.0/z**5 + 262144.0/z**6 + 2097152.0/z**7 + 16777216.0/z**8 + 134217728.0/z**9

# %%
import sympy
import matplotlib.pyplot as plt

def z_transform(x, z):
    X = sum(x[n] * z**(-n) for n in range(len(x)))
    return X

n_values = 10
x = [2**n for n in range(n_values)] 

z_values = [n for n in range(1, n_values + 1)] 
X_z_values = [z_transform(x, z) for z in z_values] 

a = 2  # Значение a
X_az_values = [z_transform([a**n * x[n] for n in range(n_values)], 1 / a * z) for z in z_values] 

plt.plot(z_values, X_z_values, label='X(z)')
plt.plot(z_values, X_az_values, label='X(a^(-1)z)')
plt.xlabel('z')
plt.ylabel('X(z)')
plt.title('Z-преобразование X(z) и X(a^(-1)z)')
plt.legend()
plt.grid()
plt.show()

# %%
pip install lcapy
# Out:
# Requirement already satisfied: lcapy in c:\users\user\anaconda3\lib\site-packages (1.19)
# Requirement already satisfied: IPython in c:\users\user\anaconda3\lib\site-packages (from lcapy) (8.12.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from lcapy) (3.7.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from lcapy) (3.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from lcapy) (1.24.3)
# Requirement already satisfied: property-cached in c:\users\user\anaconda3\lib\site-packages (from lcapy) (1.6.4)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from lcapy) (1.10.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from lcapy) (68.0.0)
# Requirement already satisfied: sympy>=1.10.1 in c:\users\user\anaconda3\lib\site-packages (from lcapy) (1.11.1)
# Requirement already satisfied: wheel in c:\users\user\anaconda3\lib\site-packages (from lcapy) (0.38.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy>=1.10.1->lcapy) (1.3.0)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (5.7.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from IPython->lcapy) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->lcapy) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->IPython->lcapy) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->lcapy) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->lcapy) (1.16.0)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->lcapy) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->lcapy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->IPython->lcapy) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lcapy as lc
import numpy as np
import matplotlib.pyplot as plt

n = lc.n

# Выражение 2^n
xk = 2**n
X0 = xk.ZT()
print("Z-преобразование для 2^n:")
print(X0)

# Выражение n^2
xk = n**2
X1 = xk.ZT()
print("Z-преобразование для n^2:")
print(X1)

# Построение графика z-преобразования для 2^n
n_values = 10
n_range = np.arange(0, n_values)
x = [2**n for n in n_range]

z_values = [2**n for n in n_range]
X_z_values = [X0.subs(lc.n, n) for n in n_range]

plt.figure()
plt.plot(z_values, X_z_values, label='Z-преобразование для 2^n')
plt.xlabel('z')
plt.ylabel('X(z)')
plt.title('Z-преобразование для 2^n')
plt.grid()

# Построение графика z-преобразования для n^2
n_range = np.arange(1, n_values + 1)
x = [n**2 for n in n_range]

z_values = [n**2 for n in_range]
X_z_values = [X1.subs(lc.n, n) for n in n_range]

plt.figure()
plt.plot(z_values, X_z_values, label='Z-преобразование для n^2')
plt.xlabel('z')
plt.ylabel('X(z)')
plt.title('Z-преобразование для n^2')
plt.grid()

plt.show()
# Out:
#   Cell In[16], line 38
#     z_values = [n**2 for n in_range]
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import lcapy as lc
import numpy as np
import matplotlib.pyplot as plt

n = lc.n

xk = 2**n
X0 = xk.ZT()
print("Z-преобразование для 2^n:")
print(X0)

xk = n**2
X1 = xk.ZT()
print("Z-преобразование для n^2:")
print(X1)

n_values = 10
n_range = np.arange(0, n_values)
x = [2**n for n in n_range]

z_values = [2**n for n in n_range]
X_z_values = [X0.subs(lc.n, n) for n in n_range]

plt.figure()
plt.plot(z_values, X_z_values, label='Z-преобразование для 2^n')
plt.xlabel('z')
plt.ylabel('X(z)')
plt.title('Z-преобразование для 2^n')
plt.grid()

n_range = np.arange(1, n_values + 1)
x = [n**2 for n in n_range]

z_values = [n**2 for n in n_range]
X_z_values = [X1.subs(lc.n, n) for n in n_range]

plt.figure()
plt.plot(z_values, X_z_values, label='Z-преобразование для n^2')
plt.xlabel('z')
plt.ylabel('X(z)')
plt.title('Z-преобразование для n^2')
plt.grid()

plt.show()
# Out:
# Z-преобразование для 2^n:
# z/(z - 2)
# Z-преобразование для n^2:
# z*(z + 1)/(z - 1)**3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 28
#      25 X_z_values = [X0.subs(lc.n, n) for n in n_range]
#      27 plt.figure()
# ---> 28 plt.plot(z_values, X_z_values, label='Z-преобразование для 2^n')
#      29 plt.xlabel('z')
#      30 plt.ylabel('X(z)')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:662, in Line2D.recache(self, always)
#     660 if always or self._invalidy:
#     661     yconv = self.convert_yunits(self._yorig)
# --> 662     y = _to_unmasked_float_array(yconv).ravel()
#     663 else:
#     664     y = self._y
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1335, in _to_unmasked_float_array(x)
#    1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
# -> 1335     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'ZDomainExpression'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal


def x(n):
    return n * (n >= 0)


n = np.arange(0, 100, 1)


xn = x(n)


w, h = signal.freqz(xn)


arg_H = np.angle(h)

plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.stem(n, xn, basefmt='b-')
plt.title('Сигнал x(n)')
plt.xlabel('n')
plt.ylabel('x(n)')
plt.grid(True)


plt.subplot(2, 1, 2)
plt.plot(w, 20 * np.log10(abs(h)))
plt.title('Частотные характеристики')
plt.xlabel('Частота [рад/с]')
plt.ylabel('Амплитуда [дБ]')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

b = [1]
a = [1, -1/6, -1/6]

n1 = np.arange(0, 50)
h1 = signal.lfilter(b, a, np.zeros(len(n1)))
h1[0] = 1  


s = len(h1)
n2 = np.arange(0, s)
h2 = 3/5 * (1/2) ** n2 + 2/5 * (-1/3) ** n2

plt.subplot(2, 1, 1)
plt.stem(n1, h1, basefmt='b-')
plt.grid(True)
plt.title('С помощью функции')

plt.subplot(2, 1, 2)
plt.stem(n2, h2, basefmt='b-')
plt.grid(True)
plt.title('Вычисленное вручную')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal


b = [1]
a = [1, -1/6, -1/6]


w, H = signal.freqz(b, a)


A1 = np.abs(H)
Ph1 = np.angle(H)


n = len(w)
w_manual = np.linspace(0, np.pi, n)
x = 1 - 1/6 * np.cos(w_manual) + 1/6 * np.sin(w_manual)**2 - 1/6 * np.cos(w_manual)**2
y = 1/6 * np.sin(w_manual) + 1/6 * np.sin(2 * w_manual)
A2 = 1 / np.sqrt(x**2 + y**2)
Ph2 = np.arctan2(y, -x)


plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(w, A1)
plt.grid(True)
plt.title('АЧХ с помощью Python')

plt.subplot(2, 2, 2)
plt.plot(w, Ph1)
plt.grid(True)
plt.title('ФЧХ с помощью Python')

plt.subplot(2, 2, 3)
plt.plot(w_manual, A2)
plt.grid(True)
plt.title('АЧХ вычисленное вручную')

plt.subplot(2, 2, 4)
plt.plot(w_manual, Ph2)
plt.grid(True)
plt.title('ФЧХ вычисленное вручную')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

def find_zeros(b):
    b0, b1, b2 = b

    discriminant = b1**2 - 4*b0*b2

    if discriminant >= 0:
        z1 = (-b1 + np.sqrt(discriminant)) / (2 * b2)
        z2 = (-b1 - np.sqrt(discriminant)) / (2 * b2)
    else:
        real_part = -b1 / (2 * b2)
        imag_part = np.sqrt(abs(discriminant)) / (2 * b2)
        z1 = complex(real_part, imag_part)
        z2 = complex(real_part, -imag_part)

b = [1, -5/6, 1/6]
zeros = find_zeros(b)

b = [1]
a = [1, -5/6, 1/6]


z, p, k = signal.tf2zpk(b, a)

plt.figure(figsize=(8, 6))
plt.scatter(np.real(z1), np.imag(z2), marker='o', color='blue', label='Нули')
plt.scatter(np.real(p), np.imag(p), marker='x', color='red', label='Полюса')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.title('Карта нулей и полюсов')

radius = 0.5

circle = plt.Circle((0, 0), radius, color='gray', fill=False, linestyle='dashed')
plt.gca().add_patch(circle)

plt.xlabel('Re')
plt.ylabel('Im')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 28
#      25 z, p, k = signal.tf2zpk(b, a)
#      27 plt.figure(figsize=(8, 6))
# ---> 28 plt.scatter(np.real(z1), np.imag(z2), marker='o', color='blue', label='Нули')
#      29 plt.scatter(np.real(p), np.imag(p), marker='x', color='red', label='Полюса')
#      30 plt.axhline(0, color='black', linewidth=0.5)
#
# NameError: name 'z1' is not defined

# %%
import numpy as np

def find_zeros(b):
    b0, b1, b2 = b

    # Вычисление дискриминанта
    discriminant = b1**2 - 4*b0*b2

    # Нахождение корней
    if discriminant >= 0:
        z1 = (-b1 + np.sqrt(discriminant)) / (2 * b2)
        z2 = (-b1 - np.sqrt(discriminant)) / (2 * b2)
        return [z1, z2]
    else:
        # Возвращаем комплексные корни, если дискриминант отрицателен
        real_part = -b1 / (2 * b2)
        imag_part = np.sqrt(abs(discriminant)) / (2 * b2)
        z1 = complex(real_part, imag_part)
        z2 = complex(real_part, -imag_part)
        return [z1, z2]

# Пример использования для вашего уравнения
b = [1, -5/6, 1/6]
zeros = find_zeros(b)

print("Нули передаточной функции:", zeros)
# Out:
# Нули передаточной функции: [3.0000000000000013, 1.999999999999999]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

def find_zeros(b):
    b0, b1, b2 = b

    discriminant = b1**2 - 4*b0*b2


    if discriminant >= 0:
        z1 = (-b1 + np.sqrt(discriminant)) / (2 * b2)
        z2 = (-b1 - np.sqrt(discriminant)) / (2 * b2)
        return [z1, z2]
    else:

        real_part = -b1 / (2 * b2)
        imag_part = np.sqrt(abs(discriminant)) / (2 * b2)
        z1 = complex(real_part, imag_part)
        z2 = complex(real_part, -imag_part)
        return [z1, z2]

def plot_zeros_poles(b, a):

    z, p, k = signal.tf2zpk(b, a)


    plt.figure(figsize=(8, 6))
    plt.scatter(np.real(z), np.imag(z), marker='o', color='blue', label='Нули')
    plt.scatter(np.real(p), np.imag(p), marker='x', color='red', label='Полюса')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.title('Карта нулей и полюсов')

   
    radius = 1 
    circle = plt.Circle((0, 0), radius, color='gray', fill=False, linestyle='dashed')
    plt.gca().add_patch(circle)


    numerator_zeros = find_zeros(b)
    plt.scatter(np.real(numerator_zeros), np.imag(numerator_zeros), marker='s', color='green', label='Нули (числитель)')

    plt.xlabel('Re')
    plt.ylabel('Im')
    plt.legend()

    if all(np.abs(p) < 1):
        print("Система устойчива.")
    else:
        print("Система неустойчива.")

    plt.show()

    return z, p, k

b = [1, 0, 0]
a = [1, -1/6, -1/6]
z, p, k = plot_zeros_poles(b, a)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8176\1156567277.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   z1 = (-b1 + np.sqrt(discriminant)) / (2 * b2)
# C:\Users\User\AppData\Local\Temp\ipykernel_8176\1156567277.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   z2 = (-b1 - np.sqrt(discriminant)) / (2 * b2)
# Система устойчива.

# %%
import numpy as np
import matplotlib.pyplot as plt

def direct_form_I(x, b, a):
    N = 100
    y = np.zeros(N)
    
    for n in range(N):
        if n < 10:
            y[n] = n + b[1] * y[n-1] + b[2] * y[n-2]
        else:
            y[n] = b[1] * y[n-1] + b[2] * y[n-2]
                
        
    return y



b = [1, -1/6, -1/6]
a = [1]

x = n

y_direct_form_I = direct_form_I(x, b, a)

print(y_direct_form_I)

plt.figure(figsize=(12, 8))

plt.plot(y_direct_form_I, label='Прямая форма')

plt.legend()
plt.title('Результаты фильтрации в различных формах')
plt.show()
# Out:
# [ 0.00000000e+00  1.00000000e+00  1.83333333e+00  2.52777778e+00
#   3.27314815e+00  4.03317901e+00  4.78227881e+00  5.53075703e+00
#   6.28116069e+00  7.03134705e+00 -2.21875129e+00 -8.02099293e-01
#   5.03475097e-01  4.97706993e-02 -9.22076327e-02  7.07282224e-03
#   1.41891351e-02 -3.54365955e-03 -1.77424592e-03  8.86317579e-04
#   1.47988057e-04 -1.72384273e-04  4.06603595e-06  2.80530395e-05
#  -5.35317924e-06 -3.78331004e-06  1.52274821e-06  3.76760304e-07
#  -3.16584753e-07 -1.00292586e-08  5.44356685e-08 -7.40106833e-09
#  -7.83910004e-09  2.54002806e-09  8.83178663e-10 -5.70534454e-10
#  -5.21073681e-11  1.03773637e-10 -8.61104481e-12 -1.58604320e-11
#   4.07857947e-12  1.96364209e-12 -1.00703693e-12 -1.59434194e-13
#   1.94411854e-13 -5.82960992e-15 -3.14303740e-14  6.20999731e-15
#   4.20339611e-15 -1.73556557e-15 -4.11305090e-16  3.57811777e-16
#   8.91555217e-18 -6.11212215e-17  8.70094488e-18  8.73671276e-18
#  -2.90627627e-18 -9.71739415e-19  6.46335948e-19  5.42339111e-20
#  -1.16761643e-19  1.04212887e-20  1.77233924e-20 -4.69078018e-21
#  -2.17210204e-21  1.14381370e-21  1.71381389e-22 -2.19199182e-22
#   7.96963216e-24  3.52049250e-23 -7.19575953e-24 -4.66819425e-24
#   1.97732563e-24  4.48478103e-25 -4.04300622e-25 -7.36291349e-27
#   6.86105892e-26 -1.02079460e-26 -9.73377388e-27  3.32361997e-27
#   1.06835898e-27 -7.31996493e-28 -5.60604153e-29  1.31342818e-28
#  -1.25470671e-29 -1.97992918e-29  5.39105983e-30  2.40137200e-30
#  -1.29873864e-30 -1.83772227e-31  2.47085144e-31 -1.05521528e-32
#  -3.94221652e-32  8.32905301e-33  5.18218537e-33 -2.25187306e-33
#  -4.88385384e-34  4.56709741e-34  5.27927381e-36 -7.69981691e-35]
